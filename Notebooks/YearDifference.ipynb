# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
# # codigo para juntar csv prod por spark
# df_2013_0 = pd.read_csv("1.csv")
# df_2013_1 = pd.read_csv("2.csv")
# df_2013_2 = pd.read_csv("3.csv")
# df2013 = pd.concat([df_2013_0,df_2013_1,df_2013_2])
# df2013.to_csv("year2013.csv",index=False)

# %%
# cargamos los csv del numero de reviews de cada juego por año
df2013 = pd.read_csv("year2013.csv")
df2014 = pd.read_csv("year2014.csv")
df2015 = pd.read_csv("year2015.csv")
df2016 = pd.read_csv("year2016.csv")
df2017 = pd.read_csv("year2017.csv")
df2018 = pd.read_csv("year2018.csv")
df2019 = pd.read_csv("year2019.csv")
df2020 = pd.read_csv("year2020.csv")
df2021 = pd.read_csv("year2021.csv")
years = [df2013,df2014,df2015,df2016,df2017,df2018,df2019,df2020,df2021]

# %%
reviews_per_year = [i['count'].sum() for i in years]
reviews_per_year
# Out:
# [279849, 694342, 918381, 1691309, 2683715, 2890352, 4141752, 7882424, 565245]

# %%
# numero de reviews por año (2021 no habia acabado al crearse el dataset)
plt.ticklabel_format(style='plain', axis='y')
plt.plot([2013,2014,2015,2016,2017,2018,2019,2020,2021], reviews_per_year)
plt.savefig('graficos/NumReviewsPerYear.png')

# %% [markdown]
# A continuacion mostramos los juegos más valorados cada año, podemos ver que se repiten durante años algunos que siguen triunfando(The Elder Scrolls Online) y que no tiene porque haber salido ese mismo año el juego mas valorado(Among Us se publico en 2018 pero salto a la fama en la cuarentena de 2020)

# %%
games = df2013.sort_values(by='count', ascending=False).head(25)
fig = games.plot(x='app_name', y='count', kind='bar')
plt.ticklabel_format(style='plain', axis='y')
plt.savefig('graficos/MostReviewedGame2013.png')

# %%
games = df2014.sort_values(by='count', ascending=False).head(25)
fig = games.plot(x='app_name', y='count', kind='bar')
plt.ticklabel_format(style='plain', axis='y')
plt.savefig('graficos/MostReviewedGame2014.png')

# %%
games = df2015.sort_values(by='count', ascending=False).head(25)
fig = games.plot(x='app_name', y='count', kind='bar')
plt.ticklabel_format(style='plain', axis='y')
plt.savefig('graficos/MostReviewedGame2015.png')

# %%
games = df2016.sort_values(by='count', ascending=False).head(25)
fig = games.plot(x='app_name', y='count', kind='bar')
plt.ticklabel_format(style='plain', axis='y')
plt.savefig('graficos/MostReviewedGame2016.png')

# %%
games = df2017.sort_values(by='count', ascending=False).head(25)
fig = games.plot(x='app_name', y='count', kind='bar')
plt.ticklabel_format(style='plain', axis='y')
plt.savefig('graficos/MostReviewedGame2017.png')

# %%
games = df2018.sort_values(by='count', ascending=False).head(25)
fig = games.plot(x='app_name', y='count', kind='bar')
plt.ticklabel_format(style='plain', axis='y')
plt.savefig('graficos/MostReviewedGame2018.png')

# %%
games = df2019.sort_values(by='count', ascending=False).head(25)
fig = games.plot(x='app_name', y='count', kind='bar')
plt.ticklabel_format(style='plain', axis='y')
plt.savefig('graficos/MostReviewedGame2019.png')

# %%
games = df2020.sort_values(by='count', ascending=False).head(25)
fig = games.plot(x='app_name', y='count', kind='bar')
plt.ticklabel_format(style='plain', axis='y')
plt.savefig('graficos/MostReviewedGame2020.png')

# %%
games = df2021.sort_values(by='count', ascending=False).head(25)
fig = games.plot(x='app_name', y='count', kind='bar')
plt.ticklabel_format(style='plain', axis='y')
plt.savefig('graficos/MostReviewedGame2021.png')
